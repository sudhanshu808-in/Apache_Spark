# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
data=[(10 ,'Anil',50000, 18),
(11 ,'Vikas',75000,  16),
(12 ,'Nisha',40000,  18),
(13 ,'Nidhi',60000,  17),
(14 ,'Priya',80000,  18),
(15 ,'Mohit',45000,  18),
(16 ,'Rajesh',90000, 10),
(17 ,'Raman',55000, 16),
(18 ,'Sam',65000,   17),
(15 ,'Mohit',45000,  18),
(13 ,'Nidhi',60000,  17),      
(14 ,'Priya',90000,  18),  
(18 ,'Sam',65000,   17),
 (19 ,'Sam',65000,   27),
 (19 ,'PK',65000,   27) 
     ]

my_schema = ['id','name','sal','mngr_id']

my_df = spark.createDataFrame(data,my_schema)

# %%
my_df.distinct().show()
# Out:
# +---+------+-----+-------+
# | id|  name|  sal|mngr_id|
# +---+------+-----+-------+
# | 10|  Anil|50000|     18|
# | 11| Vikas|75000|     16|
# | 12| Nisha|40000|     18|
# | 13| Nidhi|60000|     17|
# | 14| Priya|80000|     18|
# | 15| Mohit|45000|     18|
# | 16|Rajesh|90000|     10|
# | 17| Raman|55000|     16|
# | 18|   Sam|65000|     17|
# | 14| Priya|90000|     18|
# | 19|   Sam|65000|     27|
# +---+------+-----+-------+

# %%
my_df.select("name","id").distinct().show()
# Out:
# +------+---+
# |  name| id|
# +------+---+
# |  Anil| 10|
# | Vikas| 11|
# | Nisha| 12|
# | Nidhi| 13|
# | Priya| 14|
# | Mohit| 15|
# |Rajesh| 16|
# | Raman| 17|
# |   Sam| 18|
# |   Sam| 19|
# |    PK| 19|
# +------+---+

# %%
my_df.drop_duplicates(['id','name','sal','mngr_id']).show()
# Out:
# +---+------+-----+-------+
# | id|  name|  sal|mngr_id|
# +---+------+-----+-------+
# | 10|  Anil|50000|     18|
# | 11| Vikas|75000|     16|
# | 12| Nisha|40000|     18|
# | 13| Nidhi|60000|     17|
# | 14| Priya|80000|     18|
# | 15| Mohit|45000|     18|
# | 16|Rajesh|90000|     10|
# | 17| Raman|55000|     16|
# | 18|   Sam|65000|     17|
# | 14| Priya|90000|     18|
# | 19|   Sam|65000|     27|
# +---+------+-----+-------+

# %%
my_df.sort(col("id").desc(),col("mngr_id")).show()
# Out:
# +---+------+-----+-------+
# | id|  name|  sal|mngr_id|
# +---+------+-----+-------+
# | 19|   Sam|65000|     27|
# | 18|   Sam|65000|     17|
# | 18|   Sam|65000|     17|
# | 17| Raman|55000|     16|
# | 16|Rajesh|90000|     10|
# | 15| Mohit|45000|     18|
# | 15| Mohit|45000|     18|
# | 14| Priya|80000|     18|
# | 14| Priya|90000|     18|
# | 13| Nidhi|60000|     17|
# | 13| Nidhi|60000|     17|
# | 12| Nisha|40000|     18|
# | 11| Vikas|75000|     16|
# | 10|  Anil|50000|     18|
# +---+------+-----+-------+
